# %% [markdown]
# # Percobaan 3 (Word2vec NN(LSTM))
#
# ---

# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
# !pip install tensorflow
# !pip install gensim
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.4)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.1)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 55.0 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import pandas as pd
import numpy as np
import re
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, SpatialDropout1D
from gensim.models import Word2Vec
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/purbaya_purbaya_labeled.csv')

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()
factory_stop = StopWordRemoverFactory()
stop_words = factory_stop.get_stop_words()

# 2. Fungsi Preprocessing
def preprocess_teks(teks):
    if not isinstance(teks, str): # Cek agar tidak error jika data kosong
        return ""

    teks = teks.lower()
    teks = re.sub(r'[^a-zA-Z0-9\s]', '', teks)
    tokens = teks.split()

    # Filtering & Stemming
    final_tokens = []
    for token in tokens:
        # Sekarang 'stop_words' adalah list, jadi 'not in' akan bekerja
        if token not in stop_words:
            stemmed_token = stemmer.stem(token)
            final_tokens.append(stemmed_token)

    return ' '.join(final_tokens)

df['clean_teks'] = df['normalized_text'].apply(preprocess_teks)

# %%
le = LabelEncoder()
y = le.fit_transform(df['label_manual'])
print("Mapping Label:", dict(zip(le.classes_, le.transform(le.classes_))))
# Out:
# Mapping Label: {'negatif': np.int64(0), 'netral': np.int64(1), 'positif': np.int64(2)}

# %%
sentences = [text.split() for text in df['clean_teks']]
embedding_dim = 100
w2v_model = Word2Vec(sentences, vector_size=embedding_dim, window=5, min_count=1, workers=4)
print("Word2Vec Training Selesai.")
# Out:
# Word2Vec Training Selesai.

# %%
max_features = 5000 # Jumlah kosakata maksimal
tokenizer = Tokenizer(num_words=max_features, split=' ')
tokenizer.fit_on_texts(df['clean_teks'].values)

X = tokenizer.texts_to_sequences(df['clean_teks'].values)
X = pad_sequences(X) # Samakan panjang kalimat (padding)

vocab_size = len(tokenizer.word_index) + 1
print(f"Vocab Size: {vocab_size}, Panjang Sequence: {X.shape[1]}")
# Out:
# Vocab Size: 1471, Panjang Sequence: 34

# %%
embedding_matrix = np.zeros((vocab_size, embedding_dim))

for word, i in tokenizer.word_index.items():
    if word in w2v_model.wv:
        embedding_matrix[i] = w2v_model.wv[word]
    else:
        # Jika kata tidak ada di Word2Vec, berikan vektor random/nol
        embedding_matrix[i] = np.random.normal(0, np.sqrt(0.25), embedding_dim)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, weights=[embedding_matrix], input_length=X.shape[1], trainable=False))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(3, activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │       147,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout1d_1             │ ?                      │             0 │
# │ (SpatialDropout1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 147,100 (574.61 KB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 147,100 (574.61 KB)
# None

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.7563 - loss: 0.6302 - val_accuracy: 0.7867 - val_loss: 0.6547
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7739 - loss: 0.6189 - val_accuracy: 0.7867 - val_loss: 0.6531
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7356 - loss: 0.6815 - val_accuracy: 0.7867 - val_loss: 0.6445
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.7254 - loss: 0.7043 - val_accuracy: 0.7867 - val_loss: 0.6492
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 0.7737 - loss: 0.6104 - val_accuracy: 0.7867 - val_loss: 0.6472
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.7476 - loss: 0.6823 - val_accuracy: 0.7867 - val_loss: 0.6705
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.7512 - loss: 0.6708 - val_accuracy: 0.7867 - val_loss: 0.6487
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.7473 - loss: 0.6705 - val_accuracy: 0.7867 - val_loss: 0.6487
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7690 - loss: 0.6507 - val_accuracy: 0.7867 - val_loss: 0.6567
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7866 - loss: 0.5932 - val_accuracy: 0.7867 - val_loss: 0.6487
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.7343 - loss: 0.6518 - val_accuracy: 0.7867 - val_loss: 0.6524
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7579 - loss: 0.6431 - val_accuracy: 0.7867 - val_loss: 0.6445
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.7780 - loss: 0.6088 - val_accuracy: 0.7867 - val_loss: 0.6540
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.7683 - loss: 0.6070 - val_accuracy: 0.7867 - val_loss: 0.6444
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7634 - loss: 0.6460 - val_accuracy: 0.7867 - val_loss: 0.6584
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.7671 - loss: 0.6398 - val_accuracy: 0.7867 - val_loss: 0.6551
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7616 - loss: 0.6095 - val_accuracy: 0.7867 - val_loss: 0.6448
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.7494 - loss: 0.6069 - val_accuracy: 0.7867 - val_loss: 0.6470
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8188 - loss: 0.5534 - val_accuracy: 0.7867 - val_loss: 0.6308
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8227 - loss: 0.5370 - val_accuracy: 0.7867 - val_loss: 0.6475
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.8243 - loss: 0.5161 - val_accuracy: 0.7867 - val_loss: 0.6452
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 0.7972 - loss: 0.5084 - val_accuracy: 0.7867 - val_loss: 0.6295
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 315ms/step - accuracy: 0.8148 - loss: 0.5325 - val_accuracy: 0.8133 - val_loss: 0.6169
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 234ms/step - accuracy: 0.8257 - loss: 0.4844 - val_accuracy: 0.7733 - val_loss: 0.6190
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7766 - loss: 0.5370 - val_accuracy: 0.8133 - val_loss: 0.6196
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8420 - loss: 0.4175 - val_accuracy: 0.7867 - val_loss: 0.6198
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8205 - loss: 0.4658 - val_accuracy: 0.7867 - val_loss: 0.6171
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8677 - loss: 0.4828 - val_accuracy: 0.8133 - val_loss: 0.6109
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.8325 - loss: 0.4943 - val_accuracy: 0.8000 - val_loss: 0.6094
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8023 - loss: 0.4969 - val_accuracy: 0.8133 - val_loss: 0.6051
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8434 - loss: 0.4230 - val_accuracy: 0.8000 - val_loss: 0.6030
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.8218 - loss: 0.4300 - val_accuracy: 0.8133 - val_loss: 0.6023
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.8331 - loss: 0.4720 - val_accuracy: 0.8133 - val_loss: 0.6101
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8028 - loss: 0.5027 - val_accuracy: 0.8000 - val_loss: 0.6031
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7882 - loss: 0.5002 - val_accuracy: 0.8133 - val_loss: 0.6046
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7828 - loss: 0.4553 - val_accuracy: 0.8000 - val_loss: 0.6082
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8658 - loss: 0.4212 - val_accuracy: 0.8133 - val_loss: 0.6348
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8718 - loss: 0.4719 - val_accuracy: 0.8000 - val_loss: 0.6227
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.8231 - loss: 0.4570 - val_accuracy: 0.7600 - val_loss: 0.6116
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8672 - loss: 0.4033 - val_accuracy: 0.8000 - val_loss: 0.6082
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8718 - loss: 0.3889 - val_accuracy: 0.8133 - val_loss: 0.6122
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8605 - loss: 0.4123 - val_accuracy: 0.8133 - val_loss: 0.6194
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8196 - loss: 0.4328 - val_accuracy: 0.8267 - val_loss: 0.6007
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.8340 - loss: 0.4547 - val_accuracy: 0.8267 - val_loss: 0.6072
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.8456 - loss: 0.3964 - val_accuracy: 0.8133 - val_loss: 0.6098
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.8414 - loss: 0.4653 - val_accuracy: 0.8000 - val_loss: 0.6162
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8511 - loss: 0.4414 - val_accuracy: 0.7867 - val_loss: 0.6281
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8062 - loss: 0.4848 - val_accuracy: 0.8133 - val_loss: 0.6027
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8996 - loss: 0.3689 - val_accuracy: 0.8000 - val_loss: 0.6030
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8535 - loss: 0.4268 - val_accuracy: 0.8267 - val_loss: 0.6020
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.8166 - loss: 0.4773 - val_accuracy: 0.7867 - val_loss: 0.5964
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.7927 - loss: 0.4560 - val_accuracy: 0.8000 - val_loss: 0.6034
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.8692 - loss: 0.3659 - val_accuracy: 0.8267 - val_loss: 0.5917
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8344 - loss: 0.4109 - val_accuracy: 0.8267 - val_loss: 0.5870
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8892 - loss: 0.3846 - val_accuracy: 0.8000 - val_loss: 0.6086
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8216 - loss: 0.3977 - val_accuracy: 0.8267 - val_loss: 0.5881

# %%
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)

print("\n--- Laporan Klasifikasi LSTM ---")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 548ms/step
#
# --- Laporan Klasifikasi LSTM ---
#               precision    recall  f1-score   support
#
#      negatif       0.00      0.00      0.00         6
#       netral       0.83      0.98      0.90        59
#      positif       0.80      0.40      0.53        10
#
#     accuracy                           0.83        75
#    macro avg       0.54      0.46      0.48        75
# weighted avg       0.76      0.83      0.78        75
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(f"Akurasi Model LSTM: {accuracy * 100:.2f}%")
# Out:
# Akurasi Model LSTM: 82.67%
